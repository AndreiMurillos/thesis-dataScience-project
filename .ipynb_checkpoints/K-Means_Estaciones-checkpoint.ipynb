# %% [markdown]
# # ANALISIS DE ESTACIONES: CLUSTERS SIN ESTANDARIZACION

# %%
import pandas as pd

# Cargando el archivo CSV
file_path = './EstacionesTxt/datos2000-2021.csv'

#Incluir Latitud y Longitud
data = pd.read_csv(file_path)

# No Incluir Latitud y Longitud
# data = pd.read_csv(file_path, usecols=lambda column: column not in ['Latitud', 'Longitud'])

# Mostrando las primeras filas para entender la estructura de los datos
data.head()
# Out:
#                      Estacion  precEne  precFeb  precMar  precAbr  precMay  \
# 0                 EstacionAgs   14.066   9.4222   5.2783   7.4342   17.962
# 1                EstacionAgs2    9.416  15.1170   7.1692   7.9846   19.752
# 2  EstacionAlamitosCampamento   18.823  22.3350  14.3000   6.2428   29.318
# 3         EstacionArroyoHondo   12.750  18.9580   3.5454   2.2307   16.058
# 4          EstacionCalvillito   15.108  10.7220   5.4631   5.9891   22.318
#
#    precJun  precJul  precAgo  precSep  ...  tempMinJun  tempMinJul  \
# 0   90.897   125.42  117.740   92.461  ...     15.5200     14.7180
# 1  107.240   125.69  115.100   97.483  ...     14.3820     13.5310
# 2  134.210   165.95  145.060  127.790  ...      9.6760      9.5647
# 3   99.015   102.54   89.446   89.338  ...      9.1218      9.4489
# 4   92.367   127.24  112.580   95.897  ...     12.2660     12.1010
#
#    tempMinAgo  tempMinSep  tempMinOct  tempMinNov  tempMinDic  Latitud  \
# 0     14.6060     14.0690     11.3790      7.6483      5.5909   21.896
# 1     13.3640     11.1290      8.9059      5.7812      3.4615   21.906
# 2      9.6466      9.8021      6.7424      4.1742      2.3754   22.178
# 3      8.1029      8.1961      6.2220      1.6666      0.3980   22.183
# 4     11.7490     11.1140      7.4023      3.4650      1.3783   21.835
#
#    Longitud  Grupo
# 0  -102.309      1
# 1  -102.265      1
# 2  -102.586      2
# 3  -102.208      3
# 4  -102.183      3
#
# [5 rows x 52 columns]

# %%
# Obteniendo los nombres de las columnas para identificar la columna a excluir
column_names = data.columns
column_names
# Eliminando la columna 'Estacion ' con el espacio al final
#data_clustering = data.drop(['Estacion','Latitud','Longitud'], axis=1)

data_clustering = data.drop(['Estacion','evaEne','evaFeb','evaMar','evaAbr','evaMay','evaJun','evaJul','evaAgo','evaSep','evaOct','evaNov','evaDic'], axis=1)

# Verificando si hay valores faltantes en el conjunto de datos
missing_values = data_clustering.isnull().sum()

missing_values
# Out:
# precEne       0
# precFeb       0
# precMar       0
# precAbr       0
# precMay       0
# precJun       0
# precJul       0
# precAgo       0
# precSep       0
# precOct       0
# precNov       0
# precDic       0
# tempMaxEne    0
# tempMaxFeb    0
# tempMaxMar    0
# tempMaxAbr    0
# tempMaxMay    0
# tempMaxJun    0
# tempMaxJul    0
# tempMaxAgo    0
# tempMaxSep    0
# tempMaxOct    0
# tempMaxNov    0
# tempMaxDic    0
# tempMinEne    0
# tempMinFeb    0
# tempMinMar    0
# tempMinAbr    0
# tempMinMay    0
# tempMinJun    0
# tempMinJul    0
# tempMinAgo    0
# tempMinSep    0
# tempMinOct    0
# tempMinNov    0
# tempMinDic    0
# Latitud       0
# Longitud      0
# Grupo         0
# dtype: int64

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# Rango de número de clusters a probar
range_clusters = range(1, 11)

# Lista para almacenar la suma de los cuadrados dentro del grupo para cada número de clusters
wcss = []

# Calculando WCSS para cada número de clusters
for k in range_clusters:
    kmeans = KMeans(n_clusters=k, init='k-means++', n_init=10, random_state=42)
    kmeans.fit(data_clustering)
    wcss.append(kmeans.inertia_)

# Gráfico del método del codo
plt.figure(figsize=(10, 6))
plt.plot(range_clusters, wcss, marker='o', linestyle='-', color='b')
plt.title('El Método del Codo para Determinar el Número Óptimo de Clusters')
plt.xlabel('Número de clusters')
plt.ylabel('WCSS')
plt.xticks(range_clusters)
plt.grid(True)
plt.show()

# %%
# Realizando el análisis de clustering con 4 clusters
kmeans_optimo = KMeans(n_clusters=3, init='k-means++', random_state=42)
clusters = kmeans_optimo.fit_predict(data_clustering)

# Añadiendo la asignación de cluster al conjunto de datos original para análisis
data_clustered = data.copy()
data_clustered['Cluster'] = clusters

# Mostrando las primeras filas del conjunto de datos con la asignación de cluster
data_clustered.head()
# Out:
# C:\Users\carli\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#                      Estacion  precEne  precFeb  precMar  precAbr  precMay  \
# 0                 EstacionAgs   14.066   9.4222   5.2783   7.4342   17.962
# 1                EstacionAgs2    9.416  15.1170   7.1692   7.9846   19.752
# 2  EstacionAlamitosCampamento   18.823  22.3350  14.3000   6.2428   29.318
# 3         EstacionArroyoHondo   12.750  18.9580   3.5454   2.2307   16.058
# 4          EstacionCalvillito   15.108  10.7220   5.4631   5.9891   22.318
#
#    precJun  precJul  precAgo  precSep  ...  tempMinJul  tempMinAgo  \
# 0   90.897   125.42  117.740   92.461  ...     14.7180     14.6060
# 1  107.240   125.69  115.100   97.483  ...     13.5310     13.3640
# 2  134.210   165.95  145.060  127.790  ...      9.5647      9.6466
# 3   99.015   102.54   89.446   89.338  ...      9.4489      8.1029
# 4   92.367   127.24  112.580   95.897  ...     12.1010     11.7490
#
#    tempMinSep  tempMinOct  tempMinNov  tempMinDic  Latitud  Longitud  Grupo  \
# 0     14.0690     11.3790      7.6483      5.5909   21.896  -102.309      1
# 1     11.1290      8.9059      5.7812      3.4615   21.906  -102.265      1
# 2      9.8021      6.7424      4.1742      2.3754   22.178  -102.586      2
# 3      8.1961      6.2220      1.6666      0.3980   22.183  -102.208      3
# 4     11.1140      7.4023      3.4650      1.3783   21.835  -102.183      3
#
#    Cluster
# 0        1
# 1        1
# 2        2
# 3        0
# 4        1
#
# [5 rows x 53 columns]

# %%
# Calculando los valores medios de cada variable para cada cluster
cluster_means = data_clustered['Cluster'].mean()

cluster_means
# Out:
# 0.75

# %%
from sklearn.decomposition import PCA
import seaborn as sns

# Reduciendo la dimensionalidad para poder visualizar los clusters
pca = PCA(n_components=2)
principal_components = pca.fit_transform(data_clustering)

# Creando un DataFrame para la visualización
df_pca = pd.DataFrame(data=principal_components, columns=['PC1', 'PC2'])
df_pca['Cluster'] = clusters

# Gráfico de los clusters
plt.figure(figsize=(12, 8))
sns.scatterplot(x='PC1', y='PC2', hue='Cluster', data=df_pca, palette='Set1', s=100, alpha=0.7)
plt.title('Visualización de Clusters de Estaciones Meteorológicas')
plt.xlabel('Componente Principal 1')
plt.ylabel('Componente Principal 2')
plt.legend(title='Cluster')
plt.grid(True)
plt.show()
# Out:
# C:\Users\carli\anaconda3\lib\site-packages\seaborn\_core.py:1225: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\carli\anaconda3\lib\site-packages\seaborn\_core.py:1225: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\carli\anaconda3\lib\site-packages\seaborn\_core.py:1225: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\carli\anaconda3\lib\site-packages\seaborn\_core.py:1225: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead

# %%
import plotly.express as px

# Añadiendo los nombres de las estaciones al DataFrame para la visualización
df_pca['Estacion'] = data['Estacion']

# Gráfico interactivo con Plotly
fig = px.scatter(df_pca, x='PC1', y='PC2', color='Cluster', 
                 hover_data=['Estacion'], 
                 title='Visualización Interactiva de Clusters de Estaciones Meteorológicas',
                 labels={'PC1': 'Componente Principal 1', 'PC2': 'Componente Principal 2'})
fig.update_traces(marker=dict(size=12, line=dict(width=2, color='DarkSlateGrey')))
fig.show()
# Out:
# <div>                            <div id="f5ba9050-a71a-49fc-ab4d-07b711cc9bf1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f5ba9050-a71a-49fc-ab4d-07b711cc9bf1")) {                    Plotly.newPlot(                        "f5ba9050-a71a-49fc-ab4d-07b711cc9bf1",                        [{"customdata":[["EstacionAgs"],["EstacionAgs2"],["EstacionAlamitosCampamento"],["EstacionArroyoHondo"],["EstacionCalvillito"],["EstacionCalvillo"],["EstacionCanadaHonda"],["EstacionCieneguilla"],["EstacionCosio"],["EstacionElChayote"],["EstacionElNovillo"],["EstacionElOcote"],["EstacionElOcoteCalvillo"],["EstacionElTule"],["EstacionJesusMaria"],["EstacionJesusTeran"],["EstacionLaLabor"],["EstacionLaPostaUAA"],["EstacionLasFraguas"],["EstacionLasPresas"],["EstacionLaTinaja"],["EstacionLaTinajaSanJose"],["EstacionLosAlisos"],["EstacionLosConos"],["EstacionMalpaso"],["EstacionMesillas"],["EstacionMilpillasDeArriba"],["EstacionMontoro"],["EstacionPabellonCampoEmpresarial"],["EstacionPabellonDeArteaga"],["EstacionPaloAlto"],["EstacionPenuelas"],["EstacionPresaCanutillo"],["EstacionPresaElNiagara"],["EstacionPresaJocoque"],["EstacionPresaLaCodorniz"],["EstacionPresaMediaLuna"],["EstacionPresaPlutarcoEliasCalles"],["EstacionPresaPotrerillos"],["EstacionPuertoDeLaConcepcion"],["EstacionRanchoSeco"],["EstacionRanchoViejo"],["EstacionRinconDeRommos"],["EstacionSanBartolo"],["EstacionSandovales"],["EstacionSanFranciscoDeLosRomo"],["EstacionSanGil"],["EstacionSanIsidro"],["EstacionTepetatillo"],["EstacionTepezala"],["EstacionVenadero"],["EstacionVillaJuarez"]],"hovertemplate":"Componente Principal 1=%{x}\u003cbr\u003eComponente Principal 2=%{y}\u003cbr\u003eEstacion=%{customdata[0]}\u003cbr\u003eCluster=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[1,1,2,0,1,2,1,1,0,0,1,2,2,0,1,0,1,1,0,0,1,2,2,1,1,0,2,1,0,0,1,1,1,1,0,2,2,0,0,1,0,1,0,1,0,0,0,0,0,0,1,0],"coloraxis":"coloraxis","symbol":"circle","line":{"color":"DarkSlateGrey","width":2},"size":12},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[5.745946488540244,12.134205912664006,80.13491335627066,-23.8667823479724,6.055536298419075,43.98512554890733,-10.996255114093955,-3.116730061859361,-42.743007900022285,-41.156648641875165,-8.07446969138301,42.804940377183854,65.13825239577017,-18.874673645470665,0.6593255466121356,-17.386667011550635,18.905409833462723,-7.282168385012118,-28.449161952719944,-15.206344986553253,2.293342982318767,46.19701736938754,107.06514697229021,-6.742380954604446,16.742500980491126,-56.73374092159815,51.559230223523905,3.4340399209021975,-30.241246121104858,-27.847525037217743,-4.7961081283294815,13.405770737366735,21.75681224564748,17.23571818562479,-22.51338322859923,45.45807184282716,72.42230127094854,-19.01100697328293,-19.34961885429823,-1.5785986128783422,-55.817703223579905,23.87277092168832,-46.2419656357379,12.476278161145292,-26.138076978744234,-37.890818498036346,-42.12607259868009,-21.1519583874544,-13.581367324953396,-27.793962179225122,2.9846752844997124,-35.75888945965354],"xaxis":"x","y":[-1.199914833286023,13.789658555490833,31.348915030915563,30.11326480566496,6.755043244652046,-14.0561110096888,0.6516586593992822,-13.620616066018824,2.9466420526076496,0.5094668851656928,5.535879236640497,-4.739636172899254,-4.557833369911832,-6.855738332517903,-6.064553267159845,9.036229579705932,-20.784247260820965,-5.91473844263702,4.5250749824689915,9.202718890614552,-3.873088220150398,15.491038206048898,9.933427436011902,-6.53731405415436,-10.537434246241506,-5.717712881703849,1.029105971725046,-5.226991938688799,1.00915692264022,0.8150472120510137,2.1279116148166337,-2.1255524351023567,0.3287894446862641,-3.043393263775209,1.6329092627345432,-13.381459133978273,-19.5350 ...

# %% [markdown]
# # ANALISIS DE ESTACIONES: CLUSTERS EN MAPA SIN ESTANDARIZACION

# %%
import pandas as pd
from sklearn.cluster import KMeans

# Cargar el archivo CSV
file_path_csv = './EstacionesTxt/datos2000-2021.csv'
data_with_coords = pd.read_csv(file_path_csv)

# Verificamos las primeras filas del conjunto de datos para asegurarnos de que se ha cargado correctamente
data_with_coords.head()
# Out:
#                      Estacion  precEne  precFeb  precMar  precAbr  precMay  \
# 0                 EstacionAgs   14.066   9.4222   5.2783   7.4342   17.962
# 1                EstacionAgs2    9.416  15.1170   7.1692   7.9846   19.752
# 2  EstacionAlamitosCampamento   18.823  22.3350  14.3000   6.2428   29.318
# 3         EstacionArroyoHondo   12.750  18.9580   3.5454   2.2307   16.058
# 4          EstacionCalvillito   15.108  10.7220   5.4631   5.9891   22.318
#
#    precJun  precJul  precAgo  precSep  ...  tempMinJun  tempMinJul  \
# 0   90.897   125.42  117.740   92.461  ...     15.5200     14.7180
# 1  107.240   125.69  115.100   97.483  ...     14.3820     13.5310
# 2  134.210   165.95  145.060  127.790  ...      9.6760      9.5647
# 3   99.015   102.54   89.446   89.338  ...      9.1218      9.4489
# 4   92.367   127.24  112.580   95.897  ...     12.2660     12.1010
#
#    tempMinAgo  tempMinSep  tempMinOct  tempMinNov  tempMinDic  Latitud  \
# 0     14.6060     14.0690     11.3790      7.6483      5.5909   21.896
# 1     13.3640     11.1290      8.9059      5.7812      3.4615   21.906
# 2      9.6466      9.8021      6.7424      4.1742      2.3754   22.178
# 3      8.1029      8.1961      6.2220      1.6666      0.3980   22.183
# 4     11.7490     11.1140      7.4023      3.4650      1.3783   21.835
#
#    Longitud  Grupo
# 0  -102.309      1
# 1  -102.265      1
# 2  -102.586      2
# 3  -102.208      3
# 4  -102.183      3
#
# [5 rows x 52 columns]

# %%
# Preparando los datos para el clustering, excluyendo las columnas 'Latitud', 'Longitud' y 'Estacion'

#Sin incluir Latitud y Longitud
#data_for_clustering = data_with_coords.drop(['Estacion', 'Latitud', 'Longitud'], axis=1)

#Incluir Latitud y Longitud
data_for_clustering = data_with_coords.drop(['Estacion','evaEne','evaFeb','evaMar','evaAbr','evaMay','evaJun','evaJul','evaAgo','evaSep','evaOct','evaNov','evaDic'], axis=1)

# Entrenando el modelo K-Means con 4 clusters, como se hizo en el notebook del usuario
kmeans = KMeans(n_clusters=3, random_state=42)
clusters = kmeans.fit_predict(data_for_clustering)

# Añadiendo la asignación de cluster al conjunto de datos original
data_with_coords['Cluster'] = clusters

# Mostrando las primeras filas con la asignación de cluster para verificar
data_with_coords.head()
# Out:
# C:\Users\carli\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#                      Estacion  precEne  precFeb  precMar  precAbr  precMay  \
# 0                 EstacionAgs   14.066   9.4222   5.2783   7.4342   17.962
# 1                EstacionAgs2    9.416  15.1170   7.1692   7.9846   19.752
# 2  EstacionAlamitosCampamento   18.823  22.3350  14.3000   6.2428   29.318
# 3         EstacionArroyoHondo   12.750  18.9580   3.5454   2.2307   16.058
# 4          EstacionCalvillito   15.108  10.7220   5.4631   5.9891   22.318
#
#    precJun  precJul  precAgo  precSep  ...  tempMinJul  tempMinAgo  \
# 0   90.897   125.42  117.740   92.461  ...     14.7180     14.6060
# 1  107.240   125.69  115.100   97.483  ...     13.5310     13.3640
# 2  134.210   165.95  145.060  127.790  ...      9.5647      9.6466
# 3   99.015   102.54   89.446   89.338  ...      9.4489      8.1029
# 4   92.367   127.24  112.580   95.897  ...     12.1010     11.7490
#
#    tempMinSep  tempMinOct  tempMinNov  tempMinDic  Latitud  Longitud  Grupo  \
# 0     14.0690     11.3790      7.6483      5.5909   21.896  -102.309      1
# 1     11.1290      8.9059      5.7812      3.4615   21.906  -102.265      1
# 2      9.8021      6.7424      4.1742      2.3754   22.178  -102.586      2
# 3      8.1961      6.2220      1.6666      0.3980   22.183  -102.208      3
# 4     11.1140      7.4023      3.4650      1.3783   21.835  -102.183      3
#
#    Cluster
# 0        1
# 1        1
# 2        2
# 3        0
# 4        1
#
# [5 rows x 53 columns]

# %%
import folium

# Calculando la ubicación promedio de todas las estaciones para centrar el mapa
lat_promedio = data_with_coords['Latitud'].mean()
long_promedio = data_with_coords['Longitud'].mean()

# Creando un mapa centrado en la ubicación promedio
mapa = folium.Map(location=[lat_promedio, long_promedio], zoom_start=10)

# Colores para los diferentes clusters
colores = ['red', 'green', 'blue','purple','black','orange']

# Añadiendo los puntos al mapa
for _, row in data_with_coords.iterrows():
    folium.CircleMarker(
        location=[row['Latitud'], row['Longitud']],
        radius=5,
        color=colores[row['Cluster']],
        fill=True,
        fill_color=colores[row['Cluster']],
        fill_opacity=0.7,
        popup=row['Estacion']
    ).add_to(mapa)

mapa  # Mostrando el mapa con los puntos de cluster
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_129701a702fae9acd8a9bbf9e7618295 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_129701a702fae9acd8a9bbf9e7618295&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_129701a702fae9acd8a9bbf9e7618295 = L.map(
#                 &quot;map_129701a702fae9acd8a9bbf9e7618295&quot;,
#                 {
#                     center: [21.996, -102.31342307692306],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ef789271599bfe3cf3862cfc02a89ac4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_ef789271599bfe3cf3862cfc02a89ac4.addTo(map_129701a702fae9acd8a9bbf9e7618295);
#
#
#             var circle_marker_d589d5e9e9afb762ff0923c4296c2add = L.circleMarker(
#                 [21.896, -102.309],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_129701a702fae9acd8a9bbf9e7618295);
#
#
#         var popup_791865844d26432c9b18ff7f0bc5ab11 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_84292120747352023a5e19fe814577cb = $(`&lt;div id=&quot;html_84292120747352023a5e19fe814577cb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;EstacionAgs&lt;/div&gt;`)[0];
#                 popup_791865844d26432c9b18ff7f0bc5ab11.setContent(html_84292120747352023a5e19fe814577cb);
#
#
#
#         circle_marker_d589d5e9e9afb762ff0923c4296c2add.bindPopup(popup_791865844d26432c9b18ff7f0bc5ab11)
#         ;
#
#
#
#
#             var circle_marker_28d5a7da07fdf622bbd3a63047ea7095 = L.circleMarker(
#                 [21.906, -102.265],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_129701a702fae9acd8a9bbf9e7618295);
#
#
#         var popup_9085a4e985280f6bab6e5fdf2dc6db47 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_af73286106ff341421d4558dcaa2ebd9 = $(`&lt;div id=&quot;html_af73286106ff341421d4558dcaa2ebd9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;EstacionAgs2&lt;/div&gt;`)[0];
#                 popup_9085a4e985280f6bab6e5fdf2dc6db47.setContent(html_af73286106ff341421d4558dcaa2ebd9);
#
#
#
#         circle_marker_28d5a7da07fdf622bbd3a63047ea7095.bindPopup(popup_9085a4e985280f6bab6e5fdf2dc6db47)
#         ;
#
#
#
#
#             var circle_marker_68e0522b2f5c992e56060d8a4074f93c = L.circleMarker(
#                 [22.178, -102.586],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_129701a702fae9acd8a9bbf9e7618295);
#
#
#         var popup_454f913344e57e475fce0309d367195f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e4abc46449a7ccad1145a2de01ac1384 = $(`&lt;div id=&quot;html_e4abc46449a7ccad1145a2de01ac1384&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;EstacionAlamitosCampamento&lt;/div&gt;`)[0];
#                 popup_454f913344e57e475fce0309d367195f.setContent(html_e4abc46449a7ccad1145a2de01ac1384);
#
#
#
#         circle_marker_68e0522b2f5c992e56060d8a4074f93c.bindPopup(popup_454f913344e57e475fce0309d367195f)
#         ;
#
#
#
#
#             var circle_marker_e6c74b9a4b746e7234c0f79ca3a611ee = L.circleMarker(
#                 [22.183, -102.208],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;:

# %% [markdown]
# # ANALISIS DE ESTACIONES: CLUSTERS EN MAPA CON ESTANDARIZACION

# %%
from sklearn.preprocessing import StandardScaler

# Preparando los datos para el escalado

#Sin Incluir Latitud y Longitud
#data_for_scaling = data_with_coords.drop(['Estacion', 'Latitud', 'Longitud','Cluster'], axis=1)

#Incluir Latitud y Longitud
data_for_scaling = data_with_coords.drop(['Estacion','Cluster','evaEne','evaFeb','evaMar','evaAbr','evaMay','evaJun','evaJul','evaAgo','evaSep','evaOct','evaNov','evaDic'], axis=1)

# Inicializando y aplicando el StandardScaler
scaler = StandardScaler()
scaled_data = scaler.fit_transform(data_for_scaling)

# Reentrenando el modelo K-Means con los datos escalados
kmeans_scaled = KMeans(n_clusters=3, random_state=42)
clusters_scaled = kmeans_scaled.fit_predict(scaled_data)

# Añadiendo la nueva asignación de cluster al conjunto de datos original
data_with_coords['Cluster_Scaled'] = clusters_scaled

# Mostrando las primeras filas con la nueva asignación de cluster para verificar
data_with_coords.head()
# Out:
# C:\Users\carli\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#                      Estacion  precEne  precFeb  precMar  precAbr  precMay  \
# 0                 EstacionAgs   14.066   9.4222   5.2783   7.4342   17.962
# 1                EstacionAgs2    9.416  15.1170   7.1692   7.9846   19.752
# 2  EstacionAlamitosCampamento   18.823  22.3350  14.3000   6.2428   29.318
# 3         EstacionArroyoHondo   12.750  18.9580   3.5454   2.2307   16.058
# 4          EstacionCalvillito   15.108  10.7220   5.4631   5.9891   22.318
#
#    precJun  precJul  precAgo  precSep  ...  tempMinAgo  tempMinSep  \
# 0   90.897   125.42  117.740   92.461  ...     14.6060     14.0690
# 1  107.240   125.69  115.100   97.483  ...     13.3640     11.1290
# 2  134.210   165.95  145.060  127.790  ...      9.6466      9.8021
# 3   99.015   102.54   89.446   89.338  ...      8.1029      8.1961
# 4   92.367   127.24  112.580   95.897  ...     11.7490     11.1140
#
#    tempMinOct  tempMinNov  tempMinDic  Latitud  Longitud  Grupo  Cluster  \
# 0     11.3790      7.6483      5.5909   21.896  -102.309      1        1
# 1      8.9059      5.7812      3.4615   21.906  -102.265      1        1
# 2      6.7424      4.1742      2.3754   22.178  -102.586      2        2
# 3      6.2220      1.6666      0.3980   22.183  -102.208      3        0
# 4      7.4023      3.4650      1.3783   21.835  -102.183      3        1
#
#    Cluster_Scaled
# 0               1
# 1               0
# 2               2
# 3               2
# 4               0
#
# [5 rows x 54 columns]

# %%
# Creando un nuevo mapa centrado en la ubicación promedio
mapa_escalado = folium.Map(location=[lat_promedio, long_promedio], zoom_start=10)

# Añadiendo los puntos al mapa con la nueva asignación de cluster
for _, row in data_with_coords.iterrows():
    folium.CircleMarker(
        location=[row['Latitud'], row['Longitud']],
        radius=5,
        color=colores[row['Cluster_Scaled']],
        fill=True,
        fill_color=colores[row['Cluster_Scaled']],
        fill_opacity=0.7,
        popup=row['Estacion']
    ).add_to(mapa_escalado)

mapa_escalado  # Mostrando el mapa con los puntos de cluster escalados
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_329e0342506d31bbdc402583ad758bd6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_329e0342506d31bbdc402583ad758bd6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_329e0342506d31bbdc402583ad758bd6 = L.map(
#                 &quot;map_329e0342506d31bbdc402583ad758bd6&quot;,
#                 {
#                     center: [21.996, -102.31342307692306],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2ce80eab8db99ae1f1bd542f190aff7a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_2ce80eab8db99ae1f1bd542f190aff7a.addTo(map_329e0342506d31bbdc402583ad758bd6);
#
#
#             var circle_marker_210055b8bd9786362f334d048149c082 = L.circleMarker(
#                 [21.896, -102.309],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_329e0342506d31bbdc402583ad758bd6);
#
#
#         var popup_2d1ec499789e0ace214e441176524c91 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cff86c5c3d0e2ef5e0fd2c43e6b93a6b = $(`&lt;div id=&quot;html_cff86c5c3d0e2ef5e0fd2c43e6b93a6b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;EstacionAgs&lt;/div&gt;`)[0];
#                 popup_2d1ec499789e0ace214e441176524c91.setContent(html_cff86c5c3d0e2ef5e0fd2c43e6b93a6b);
#
#
#
#         circle_marker_210055b8bd9786362f334d048149c082.bindPopup(popup_2d1ec499789e0ace214e441176524c91)
#         ;
#
#
#
#
#             var circle_marker_78edbbf9a1837b668aa01d1163c0e2f1 = L.circleMarker(
#                 [21.906, -102.265],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_329e0342506d31bbdc402583ad758bd6);
#
#
#         var popup_e0534c7802047e2ff4a8c476e6cf2ee0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f3d2b7dbca598442e1915bb42e67b7e7 = $(`&lt;div id=&quot;html_f3d2b7dbca598442e1915bb42e67b7e7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;EstacionAgs2&lt;/div&gt;`)[0];
#                 popup_e0534c7802047e2ff4a8c476e6cf2ee0.setContent(html_f3d2b7dbca598442e1915bb42e67b7e7);
#
#
#
#         circle_marker_78edbbf9a1837b668aa01d1163c0e2f1.bindPopup(popup_e0534c7802047e2ff4a8c476e6cf2ee0)
#         ;
#
#
#
#
#             var circle_marker_20c8539d2fb9069068435bdf7173bbc2 = L.circleMarker(
#                 [22.178, -102.586],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_329e0342506d31bbdc402583ad758bd6);
#
#
#         var popup_bdb68cd5aeff69a4d9c7199f377faf2a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1355130a2673d26ca2c1c30bb511dd66 = $(`&lt;div id=&quot;html_1355130a2673d26ca2c1c30bb511dd66&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;EstacionAlamitosCampamento&lt;/div&gt;`)[0];
#                 popup_bdb68cd5aeff69a4d9c7199f377faf2a.setContent(html_1355130a2673d26ca2c1c30bb511dd66);
#
#
#
#         circle_marker_20c8539d2fb9069068435bdf7173bbc2.bindPopup(popup_bdb68cd5aeff69a4d9c7199f377faf2a)
#         ;
#
#
#
#
#             var circle_marker_cdc57471d4c247f6fd04fc128ff3d28a = L.circleMarker(
#                 [22.183, -102.208],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.

# %%
# Crear un mapa base
mapa = folium.Map(location=[lat_promedio, long_promedio], zoom_start=10)

# Colores para los diferentes grupos
colores = ['red', 'blue', 'green', 'purple', 'orange', 'darkred', 'lightred', 'beige', 'darkblue', 'darkgreen',
           'cadetblue', 'darkpurple', 'white', 'pink', 'lightblue', 'lightgreen', 'gray', 'black', 'lightgray']

for _, row in data_with_coords.iterrows():
    folium.CircleMarker(
        location=[row['Latitud'], row['Longitud']],
        radius=5,
        color=colores[row['Grupo']],
        fill=True,
        fill_color=colores[row['Grupo']],
        fill_opacity=0.7,
        popup=row['Estacion']
    ).add_to(mapa)

mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7348aced40f0c2d87da1ecc7e68eb3a8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7348aced40f0c2d87da1ecc7e68eb3a8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7348aced40f0c2d87da1ecc7e68eb3a8 = L.map(
#                 &quot;map_7348aced40f0c2d87da1ecc7e68eb3a8&quot;,
#                 {
#                     center: [21.996, -102.31342307692306],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c347f1e2c2aaec45ee4197ec6c07b612 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c347f1e2c2aaec45ee4197ec6c07b612.addTo(map_7348aced40f0c2d87da1ecc7e68eb3a8);
#
#
#             var circle_marker_e89bbde8c7d4faef94474d531772528d = L.circleMarker(
#                 [21.896, -102.309],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7348aced40f0c2d87da1ecc7e68eb3a8);
#
#
#         var popup_9e5e5becb559ad375c6890a43a5ad72a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2aa317d524feb6b093bc32183c429940 = $(`&lt;div id=&quot;html_2aa317d524feb6b093bc32183c429940&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;EstacionAgs&lt;/div&gt;`)[0];
#                 popup_9e5e5becb559ad375c6890a43a5ad72a.setContent(html_2aa317d524feb6b093bc32183c429940);
#
#
#
#         circle_marker_e89bbde8c7d4faef94474d531772528d.bindPopup(popup_9e5e5becb559ad375c6890a43a5ad72a)
#         ;
#
#
#
#
#             var circle_marker_1ca3c24caf16beb538b79c5492930bd3 = L.circleMarker(
#                 [21.906, -102.265],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7348aced40f0c2d87da1ecc7e68eb3a8);
#
#
#         var popup_66225d89207c749b2bb15da59a4bcb92 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_50c05beed3db5a6f9658cd85246b7f8a = $(`&lt;div id=&quot;html_50c05beed3db5a6f9658cd85246b7f8a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;EstacionAgs2&lt;/div&gt;`)[0];
#                 popup_66225d89207c749b2bb15da59a4bcb92.setContent(html_50c05beed3db5a6f9658cd85246b7f8a);
#
#
#
#         circle_marker_1ca3c24caf16beb538b79c5492930bd3.bindPopup(popup_66225d89207c749b2bb15da59a4bcb92)
#         ;
#
#
#
#
#             var circle_marker_8aa0404818066cda3a400c8627efc9e1 = L.circleMarker(
#                 [22.178, -102.586],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7348aced40f0c2d87da1ecc7e68eb3a8);
#
#
#         var popup_89a20e4c12bca86a61bc8cfd021f7a18 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_17102bf091bf4c890612eca5fb12d595 = $(`&lt;div id=&quot;html_17102bf091bf4c890612eca5fb12d595&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;EstacionAlamitosCampamento&lt;/div&gt;`)[0];
#                 popup_89a20e4c12bca86a61bc8cfd021f7a18.setContent(html_17102bf091bf4c890612eca5fb12d595);
#
#
#
#         circle_marker_8aa0404818066cda3a400c8627efc9e1.bindPopup(popup_89a20e4c12bca86a61bc8cfd021f7a18)
#         ;
#
#
#
#
#             var circle_marker_22f81815b94ddb06dd2b678d1d253412 = L.circleMarker(
#                 [22.183, -102.208],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;purple&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;purple&quot;, &quot;fillOpacity&quo
